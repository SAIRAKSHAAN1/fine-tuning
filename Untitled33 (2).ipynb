# %%
from datasets import load_dataset, Dataset
import pandas as pd

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 49.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.5 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv(r"/content/updated_dataset2.csv")
df.head()
# Out:
#                                          instruction  \
# 0  Sterilizer - Broken Rail Lines Inside Steriliz...
# 1  Sterilizer - Broken Rail Lines Inside Steriliz...
# 2  Sterilizer - Broken Rail Lines Inside Steriliz...
# 3  Sterilizer - Broken Rail Lines Inside Steriliz...
# 4  Sterilizer - Torn Liner =>Probable Causes=> De...
#
#                                               Output  \
# 0  Isolate Sterilizer And  Remove Cage And Repair...
# 1  Line Ensure Good Welding  And Schedule Mainten...
# 2                                    Renew Rail Line
# 3                                          Supervise
# 4  Isolate Sterilizer And  Remove Cage And Repair...
#
#                                 col
# 0  You are a palm oil mills expert.
# 1  You are a palm oil mills expert.
# 2  You are a palm oil mills expert.
# 3  You are a palm oil mills expert.
# 4  You are a palm oil mills expert.

# %%
dataset = Dataset.from_pandas(df)

# %%
dataset
# Out:
# Dataset({
#     features: ['instruction', 'Output', 'col'],
#     num_rows: 1790
# })

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 500 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.1.7: Fast Llama patching. Transformers: 4.48.1.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.1.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

# Load the dataset
df = pd.read_csv(r"/content/updated_dataset2.csv")

# Create a Dataset object from the pandas DataFrame
dataset = Dataset.from_pandas(df)

# Define the prompt template
alpaca_prompt = """
### Instruction:
{}

### Input:
{}

### Response:
{}"""

# Ensure tokenizer is defined
tokenizer = AutoTokenizer.from_pretrained("unsloth/Meta-Llama-3.1-8B")  # Change model if needed
EOS_TOKEN = tokenizer.eos_token or "<|endoftext|>"  # Fallback in case EOS_TOKEN is None

# Define the formatting function with robust None handling
def formatting_prompts_func(examples):
    instructions = examples.get("col", [])  # Use .get() to avoid KeyError
    inputs = examples.get("instruction", [])
    outputs = examples.get("Output", [])

    texts = []
    for instruction, input_text, output in zip(instructions, inputs, outputs):
        # Ensure values are strings and replace None with empty strings
        instruction = str(instruction) if instruction is not None else ""
        input_text = str(input_text) if input_text is not None else ""
        output = str(output) if output is not None else ""

        # Ensure EOS_TOKEN is a string before concatenation
        eos_token = EOS_TOKEN if isinstance(EOS_TOKEN, str) else "<|endoftext|>"

        # Format text
        text = alpaca_prompt.format(instruction, input_text, output) + eos_token
        texts.append(text)

    return {"text": texts}

# Map the formatting function to the dataset
dataset = dataset.map(formatting_prompts_func, batched=True)

# Display the first example to check formatting
print(dataset[0])
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Map:   0%|          | 0/1790 [00:00<?, ? examples/s]
# {'instruction': 'Sterilizer - Broken Rail Lines Inside Sterilizer =>Probable Causes=> Defective Material', 'Output': 'Isolate Sterilizer And  Remove Cage And Repair The Rail', 'col': 'You are a palm oil mills expert.', 'text': '\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\nSterilizer - Broken Rail Lines Inside Sterilizer =>Probable Causes=> Defective Material\n\n### Response:\nIsolate Sterilizer And  Remove Cage And Repair The Rail<|end_of_text|>'}

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

# Load the dataset
df = pd.read_csv(r"/content/updated_dataset2.csv")

# Create a Dataset object from the pandas DataFrame
dataset = Dataset.from_pandas(df)

# Define the prompt template
alpaca_prompt = """
### Instruction:
{}

### Input:
{}

### Response:
{}"""





EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["col"]
    inputs       = examples["instruction"]
    outputs      = examples["Output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/1790 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['instruction', 'Output', 'col', 'text'],
#     num_rows: 1790
# })

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
effective_batch_size = 2 * 4
max_steps = (4 * len(dataset)) // (2 * 4)  # Adjusting for 4 epochs
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 4, # Set this for 1 full training run.
        max_steps = max_steps,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/1790 [00:00<?, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 5.496 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 1,790 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 895
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='895' max='895' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [895/895 53:47, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.338500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.221800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.011500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.069500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.565700</td>
# ...

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 3239.161 seconds used for training.
# 53.99 minutes used for training.
# Peak reserved memory = 6.16 GB.
# Peak reserved memory for training = 0.664 GB.
# Peak reserved memory % of max memory = 41.788 %.
# Peak reserved memory for training % of max memory = 4.504 %.

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are good at question and answering.", # instruction
        "Sterilizer - Broken Rail Lines Inside Sterilizer Defective Material", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>
# ### Instruction:
# You are good at question and answering.
#
# ### Input:
# Sterilizer - Broken Rail Lines Inside Sterilizer Defective Material
#
# ### Response:
# Isolate Sterilizer And Repair The Rail Line<|end_of_text|>

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        " Sterilizer Defective Material", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\n Sterilizer Defective Material\n\n### Response:\n Isolate Sterilizer And  Remove Cage And Repair The Rail<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        " Worn Rail Line", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\n Worn Rail Line\n\n### Response:\n Repair Rail Line<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        " Separator	High Oil Loss	", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\n Separator\tHigh Oil Loss\t\n\n### Response:\n Check Separator Dish, Check The Feeding Pump<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        "Separator-Tripping", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\nSeparator-Tripping\n\n### Response:\nCheck Motor And Drive Train<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        "Sterilizer - Torn Liner	Defective Material	", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\nSterilizer - Torn Liner\tDefective Material\t\n\n### Response:\nIsolate Sterilizer And  Remove Cage And Repair The Rail  And Line Ensure Good Welding  And Schedule Maintenance Checks Regularly  And Renew Rail Line  And Supervise<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert.", # instruction
        "Bisley Silo-High Stock Poor Kernel Quality	", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert.\n\n### Input:\nBisley Silo-High Stock Poor Kernel Quality\t\n\n### Response:\nCheck Rectify Fault<|end_of_text|>']

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "You are a palm oil mills expert answer in  3 sentance.", # instruction
        "Bisley Silo-High Stock Poor Kernel Quality	", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 190, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>\n### Instruction:\nYou are a palm oil mills expert answer in  3 sentance.\n\n### Input:\nBisley Silo-High Stock Poor Kernel Quality\t\n\n### Response:\nCheck Rectify Fault<|end_of_text|>']

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !huggingface-cli login
model.push_to_hub("sairam130/Llama-2-7b-chat-finetune1-upsloat", check_pr=True)

tokenizer.push_to_hub("sairam130/Llama-2-7b-chat-finetune1-upsloat",check_pr=True)
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `sai` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline


# Define input prompt
prompt = "Sterilizer - Broken Rail Lines Inside Sterilizer Defective Material?"

# Use FastLanguageModel for 2x faster inference
FastLanguageModel.for_inference(model)

# Generate prompt for tokenizer
input_prompt = alpaca_prompt.format(
    "You are good at question and answering.",  # instruction
    prompt,  # input
    "",  # output - leave this blank for generation!
)

# Tokenize inputs and move to GPU
inputs = tokenizer([input_prompt], return_tensors="pt").to("cuda")

# Generate output with the model
outputs = model.generate(**inputs, max_new_tokens=190, use_cache=True)

# Decode the generated output
generated_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)

# Print the generated output
print("Generated Output:", generated_output)
# Out:
# Generated Output: ['\n### Instruction:\nYou are good at question and answering.\n\n### Input:\nSterilizer - Broken Rail Lines Inside Sterilizer Defective Material?\n\n### Response:\nIsolate Sterilizer And Repair The Rail Line']

# %%
# Use the pipeline for industrial equipment solutions
industrial_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

solutions = industrial_pipeline(
    f'''
"You are a palm oil mills expert answer in  3 sentance.", # instruction
        "Bisley Silo-High Stock Poor Kernel Quality	", =>''',
    do_sample=True,
    top_k=100,
    repetition_penalty=1.5,
    num_return_sequences=1,
    top_p=0.9,
    temperature=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)

# Print the generated solution
print("Industrial Equipment Solution:", solutions[0]['generated_text'])
# Out:
# Device set to use cuda:0
# ...

# %%
# Define alpaca_prompt
alpaca_prompt = """
You are good at question and answering.
Instruction: {0}
Input: {1}
Output: {2}
"""

# Enable native 2x faster inference
FastLanguageModel.for_inference(model)

# Prepare the input tokens
inputs = tokenizer(
    [
        alpaca_prompt.format(
            "You are good at question and answering.",  # instruction
            "Sterilizer - Broken Rail Lines Inside Sterilizer Defective Material",  # input
            "",  # output - leave this blank for generation!
        )
    ],
    return_tensors="pt"
).to("cuda")

# Generate the output with proper configuration
outputs = model.generate(
    **inputs,
    do_sample=True,
    top_k=40,
    repetition_penalty=1.5,
    max_new_tokens=190,  # maximum number of tokens to generate
    use_cache=True,  # use cache to speed up inference
    top_p=0.9,  # use top-p (nucleus) sampling
    temperature=1,  # temperature for randomness
    eos_token_id=tokenizer.eos_token_id,  # end-of-sequence token ID
    max_length=100  # maximum length of generated sequence
)

# Decode the generated tokens
decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)

# Output the result
print(decoded_output)
# Out:
# Both `max_new_tokens` (=190) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
# Enable native 2x faster inference
FastLanguageModel.for_inference(model)

# Define the input prompt
prompt = "Sterilizer - Broken Rail Lines Inside Sterilizer Defective Material?"

# Prepare the input for the model
inputs = tokenizer(
    [
        f"You are good at question and answering. {prompt} =>"
    ],
    return_tensors="pt"
).to("cuda")

# Create a text streamer for real-time output
text_streamer = TextStreamer(tokenizer)

# Generate the response using the model
_ = model.generate(
    **inputs,
    streamer=text_streamer,
    max_new_tokens=128
)

# Use a pipeline for generating solutions in exactly 10 words
solution_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    do_sample=True,
    top_k=40,
    repetition_penalty=1.5,
    num_return_sequences=1,
    top_p=0.9,
    temperature=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=100,
)

# Generate the solution
sequences = solution_pipeline(f"You are an industrial equipment expert. Provide solutions in exactly 10 words answer. {prompt} =>")

# Print the results
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# [CLS] you are good at question and answering. sterilizer - broken rail lines inside sterilizer defective material? = > [SEP] to valves in large quantity # # # instruction : depericarper drum - choked with wet fibre trunking and schedule maintenance checks < | endoftext | > [SEP] to valves in and repair rectify and check and replace < | endoftext | > [SEP] to valves in and repair rectify < | endoftext | < | endoftext | > [SEP] to valves in and repair < | endoftext | < | endoftext | < | > [SEP] and schedule maintenance checks < | endoftext < | < | endoftext < | < | < | < |
# Device set to use cuda:0
# ...

# %%
model.push_to_hub("your_name/lora_model", token = "...")
tokenizer.push_to_hub("your_name/lora_model", token = "...")
